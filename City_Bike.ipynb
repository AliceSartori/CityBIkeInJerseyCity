# %%
import numpy as np
import pandas as pd

# %%
#Files to stack together
#Read the mouse data and the study results

February_2020 = pd.read_csv("JC_202002_citibike_tripdata.csv")
March_2020 = pd.read_csv("JC_202003_citibike_tripdata.csv")
April_2020 = pd.read_csv("JC_202004_citibike_tripdata.csv")
May_2020 = pd.read_csv("JC_202005_citibike_tripdata.csv")
June_2020 = pd.read_csv('JC_202006_citibike_tripdata.csv')
July_2020 = pd.read_csv('JC_202007_citibike_tripdata.csv')
August_2020 = pd.read_csv('JC_202008_citibike_tripdata.csv')
September_2020 = pd.read_csv('JC_202009_citibike_tripdata.csv')

# %%
June_2020['start station name'].unique()
# Out:
# array(['Columbus Dr at Exchange Pl', 'Heights Elevator', 'Columbus Drive',
#        'Morris Canal', 'Harborside', 'Grove St PATH', 'York St',
#        'Sip Ave', 'Hilltop', 'Oakland Ave', 'Lincoln Park',
#        'Glenwood Ave', 'Hamilton Park', 'Newport Pkwy',
#        'Baldwin at Montgomery', 'Washington St', 'Newark Ave',
#        'Bergen Ave', 'Essex Light Rail', 'Christ Hospital',
#        'Liberty Light Rail', 'Brunswick St', 'Marin Light Rail',
#        'Monmouth and 6th', 'JC Medical Center', 'Van Vorst Park',
#        'Jersey & 6th St', 'McGinley Square', 'Paulus Hook', 'Astor Place',
#        'Hoboken Ave at Monmouth St', 'City Hall', 'Dey St',
#        'Riverview Park', 'Jersey & 3rd', 'Pershing Field',
#        'Journal Square', 'Union St', 'Manila & 1st', 'Newport PATH',
#        'Warren St', 'Dixon Mills', 'Montgomery St', 'Jackson Square',
#        '5 Corners Library', 'Grand St', 'Lafayette Park',
# ...

# %%
import glob

df = pd.concat(map(pd.read_csv, glob.glob('*.csv')))

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
March_2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
df.shape
# Out:
# (247727, 18)

# %%
df['gender'] = df['gender'].astype(str)

# %%
df['Gender'] = df['gender'].replace(['0','1','2'],['Unknown','Male','Female'])

# %%
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1              242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2              124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3              104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4              228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...            ...                       ...                       ...
# 9263           597  2020-04-30 22:18:40.4140  2020-04-30 22:28:38.1280
# 9264           311  2020-04-30 22:23:18.7780  2020-04-30 22:28:30.2980
# 9265           167  2020-04-30 22:34:51.8480  2020-04-30 22:37:39.6690
# 9266           520  2020-04-30 22:50:52.2380  2020-04-30 22:59:33.1620
# 9267          1043  2020-04-30 22:54:39.0840  2020-04-30 23:12:02.1790
#
#       start station id start station name  start station latitude  \
# ...

# %%
del df['gender']

# %%
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1              242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2              124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3              104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4              228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...            ...                       ...                       ...
# 9263           597  2020-04-30 22:18:40.4140  2020-04-30 22:28:38.1280
# 9264           311  2020-04-30 22:23:18.7780  2020-04-30 22:28:30.2980
# 9265           167  2020-04-30 22:34:51.8480  2020-04-30 22:37:39.6690
# 9266           520  2020-04-30 22:50:52.2380  2020-04-30 22:59:33.1620
# 9267          1043  2020-04-30 22:54:39.0840  2020-04-30 23:12:02.1790
#
#       start station id start station name  start station latitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247727 entries, 0 to 9267
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             247727 non-null  int64
#  1   starttime                247727 non-null  object
#  2   stoptime                 247727 non-null  object
#  3   start station id         247727 non-null  int64
#  4   start station name       247727 non-null  object
#  5   start station latitude   247727 non-null  float64
#  6   start station longitude  247727 non-null  float64
#  7   end station id           247727 non-null  int64
#  8   end station name         247727 non-null  object
#  9   end station latitude     247727 non-null  float64
#  10  end station longitude    247727 non-null  float64
#  11  bikeid                   247727 non-null  int64
#  12  usertype                 247727 non-null  object
# ...

# %%
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1              242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2              124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3              104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4              228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...            ...                       ...                       ...
# 9263           597  2020-04-30 22:18:40.4140  2020-04-30 22:28:38.1280
# 9264           311  2020-04-30 22:23:18.7780  2020-04-30 22:28:30.2980
# 9265           167  2020-04-30 22:34:51.8480  2020-04-30 22:37:39.6690
# 9266           520  2020-04-30 22:50:52.2380  2020-04-30 22:59:33.1620
# 9267          1043  2020-04-30 22:54:39.0840  2020-04-30 23:12:02.1790
#
#       start station id start station name  start station latitude  \
# ...

# %%
df['Trip Year']= df.starttime.str.split('-', expand=True)[0]

# %%
df['Trip Month']= df.starttime.str.split('-', expand=True)[1]

# %%
df['Trip Year']=df['Trip Year'].astype('int')

# %%
#age of riders
df['Age'] = df['Trip Year']- df['birth year']

# %%
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1              242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2              124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3              104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4              228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...            ...                       ...                       ...
# 9263           597  2020-04-30 22:18:40.4140  2020-04-30 22:28:38.1280
# 9264           311  2020-04-30 22:23:18.7780  2020-04-30 22:28:30.2980
# 9265           167  2020-04-30 22:34:51.8480  2020-04-30 22:37:39.6690
# 9266           520  2020-04-30 22:50:52.2380  2020-04-30 22:59:33.1620
# 9267          1043  2020-04-30 22:54:39.0840  2020-04-30 23:12:02.1790
#
#       start station id start station name  start station latitude  \
# ...

# %%
df['start station name'].unique()
# Out:
# array(['Newport PATH', 'City Hall', 'Jersey & 3rd', 'McGinley Square',
#        'Baldwin at Montgomery', 'Essex Light Rail', 'Manila & 1st',
#        'Columbus Drive', 'Fairmount Ave', 'Brunswick St', 'Morris Canal',
#        'Marin Light Rail', 'Columbus Dr at Exchange Pl', 'Newark Ave',
#        'Hamilton Park', 'Brunswick & 6th', 'Astor Place',
#        'JC Medical Center', 'Harborside', 'Sip Ave', 'Washington St',
#        'Riverview Park', 'Monmouth and 6th', 'Glenwood Ave',
#        'Van Vorst Park', 'Grand St', 'Newport Pkwy', 'Warren St',
#        '5 Corners Library', 'Liberty Light Rail', 'Grove St PATH',
#        'Montgomery St', 'Oakland Ave', 'Dixon Mills', 'Hilltop',
#        'Lafayette Park', 'Christ Hospital', 'Pershing Field',
#        'Jackson Square', 'Lincoln Park', 'Dey St',
#        'Hoboken Ave at Monmouth St', 'Paulus Hook', 'Journal Square',
#        'Communipaw & Berry Lane', 'Jersey & 6th St', 'Heights Elevator',
# ...

# %%
df['bikeid'].count()
# Out:
# 247727

# %%
df['end station name'].unique()
# Out:
# array(['Hamilton Park', 'JC Medical Center', 'Monmouth and 6th',
#        'Washington St', 'Astor Place', 'Jackson Square', 'City Hall',
#        'Brunswick & 6th', 'Manila & 1st', 'Harborside',
#        'Marin Light Rail', 'Grove St PATH', 'Columbus Dr at Exchange Pl',
#        'Newark Ave', 'Warren St', 'Sip Ave', 'Glenwood Ave',
#        'Montgomery St', 'Hoboken Ave at Monmouth St', '5 Corners Library',
#        'Brunswick St', 'Jersey & 3rd', 'Liberty Light Rail',
#        'Van Vorst Park', 'Columbus Drive', 'Journal Square',
#        'Pershing Field', 'Newport PATH', 'Hilltop', 'Essex Light Rail',
#        'Grand St', 'Communipaw & Berry Lane', 'Dixon Mills',
#        'Newport Pkwy', 'Riverview Park', 'Jersey & 6th St', 'Oakland Ave',
#        'Lafayette Park', 'Paulus Hook', 'Lincoln Park',
#        'Baldwin at Montgomery', 'York St', 'Bergen Ave', 'Morris Canal',
#        'McGinley Square', 'Union St', 'Fairmount Ave', 'Dey St',
# ...

# %%
df.to_csv('df_modified_modified.csv', index=False)
